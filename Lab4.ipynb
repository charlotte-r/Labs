# %% [markdown]
# # Lab 4
# ## Charlotte Ring
# Reproduction of https://github.com/jorisvandenbossche/geopandas-tutorial/blob/master/01-introduction-geospatial-data.ipynb

# %%
# %matplotlib inline

import pandas as pd
import geopandas

pd.options.display.max_rows = 10

# %%
countries = geopandas.read_file('/Users/Charlotte/Documents/4thYear/GISIII/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp')

# %%
countries.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE                        ADMIN ADM0_A3  \
# 0         0      2  Sovereign country                         Fiji     FJI
# 1         0      2  Sovereign country  United Republic of Tanzania     TZA
# 2         0      2      Indeterminate               Western Sahara     SAH
# 3         0      2  Sovereign country                       Canada     CAN
# 4         1      2            Country     United States of America     USA
#
# ...

# %%
countries.plot()

# %%
type(countries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
countries.geometry
# Out:
# 0      (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1      POLYGON ((33.90371119710453 -0.950000000000000...
# 2      POLYGON ((-8.665589565454809 27.65642588959236...
# 3      (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4      (POLYGON ((-122.84 49.00000000000011, -120 49....
#                              ...
# 172    POLYGON ((18.82982479287395 45.90887235802528,...
# 173    POLYGON ((20.07070000000004 42.58863000000008,...
# 174    POLYGON ((20.59024654668023 41.85540891928363,...
# 175    POLYGON ((-61.68000000000001 10.76, -61.105 10...
# 176    POLYGON ((30.83385242171543 3.509171604222463,...
# Name: geometry, Length: 177, dtype: object

# %%
type(countries.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
countries.geometry.area
# Out:
# 0         1.639511
# 1        76.301964
# 2         8.603984
# 3      1712.995228
# 4      1122.281921
#           ...
# 172       8.604719
# 173       1.479321
# 174       1.231641
# 175       0.639000
# 176      51.196106
# Length: 177, dtype: float64

# %%
countries['POP_EST'].mean()
# Out:
# 41712369.84180791

# %%
africa = countries[countries['CONTINENT'] == 'Africa']

# %%
africa.plot()

# %%
print(countries.geometry[2])
# Out:
# POLYGON ((-8.665589565454809 27.65642588959236, -8.665124477564191 27.58947907155823, -8.684399786809053 27.39574412689601, -8.6872936670174 25.88105621998891, -11.96941891117116 25.93335276946827, -11.93722449385332 23.37459422453617, -12.87422156416958 23.28483226164518, -13.11875444177471 22.77122020109626, -12.92910193526353 21.32707062426756, -16.84519365077399 21.33332347257488, -17.06342322434257 20.99975210213083, -17.02042843267577 21.42231028898158, -17.00296179856109 21.42073415779658, -14.75095455571353 21.50060008390366, -14.63083268885107 21.8609398462749, -14.22116777185725 22.31016307218816, -13.89111039880905 23.6910090194593, -12.50096269372537 24.7701162785782, -12.03075883630163 26.03086619720307, -11.71821977380036 26.10409170176062, -11.39255489749701 26.88342397715439, -10.55126257978527 26.99080760345689, -10.18942420087758 26.86094472910741, -9.735343390328879 26.86094472910741, -9.41303748212448 27.08847606048857, -8.794883999049077 27.12069631602251, -8.817
# ...

# %%
cities = geopandas.read_file("/Users/Charlotte/Documents/4thYear/GISIII/ne_110m_populated_places/ne_110m_populated_places.shp")

# %%
rivers = geopandas.read_file("/Users/Charlotte/Documents/4thYear/GISIII/ne_50m_rivers_lake_centerlines/ne_50m_rivers_lake_centerlines.shp")

# %%
print(rivers.geometry[0])
# Out:
# LINESTRING (51.9371337598152 55.70106609892139, 51.88086646731369 55.68625891701544, 51.82031249962222 55.69745514553858, 51.7476018274624 55.69366250841807, 51.6628417966117 55.60817291874525, 51.57871093775964 55.59943268477065, 51.51342773400279 55.58312409100404, 51.50854492161091 55.52948639548083, 51.48583984403365 55.49640534033426, 51.36914062543957 55.46796295772435, 51.21306254869774 55.50264985760492, 51.13452148447897 55.48273346527725, 51.07934570274205 55.46759674659262, 50.98022460947817 55.46637604371949, 50.83445217522774 55.45630956063775, 50.6883789060617 55.42011139502489, 50.4118652342932 55.40119049644431, 50.07802734358711 55.38112213757665, 49.82216796867687 55.33466217681809, 49.53222656260584 55.260614325191, 49.38232421848795 55.17182037990665, 49.24808475131027 55.11301870345045)

# %%
type(countries.geometry[0])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
from shapely.geometry import Point, Polygon, LineString

# %%
p = Point(1 ,1)

# %%
print(p)
# Out:
# POINT (1 1)

# %%
polygon = Polygon([(1, 1), (2,2), (2, 1)])

# %%
ax = countries.plot(edgecolor='k', facecolor='none', figsize=(15, 10))
rivers.plot(ax=ax)
cities.plot(ax=ax, color='red')
ax.set(xlim=(-20, 60), ylim=(-40, 40))
# Out:
# [(-40, 40), (-20, 60)]

# %%
districts = geopandas.read_file("/Users/Charlotte/Documents/4thYear/GISIII/quartier_paris.geojson")

# %%
stations = geopandas.read_file("/Users/Charlotte/Documents/4thYear/GISIII/velib-disponibilite-en-temps-reel.geojson")

# %%
type(districts)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(stations)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# Both are GeoDataFrames.

# %%
districts.head()
# Out:
#      n_sq_qu    perimetre  objectid     longueur  c_qu        surface  \
# 0  750000010  2139.625388        50  2139.535591    10  271750.323937
# 1  750000016  3283.163371        56  3282.999717    16  378252.153674
# 2  750000018  4052.729521        58  4052.473226    18  798389.398463
# 3  750000025  3827.253353         7  3827.053421    25  826559.436780
# 4  750000035  2786.541926        17  2786.448978    35  417335.080621
#
#      n_sq_ar  c_quinsee                  l_qu  c_ar  \
# 0  750000003    7510302        Enfants-Rouges     3
# 1  750000004    7510404            Notre-Dame     4
# 2  750000005    7510502    Jardin-des-Plantes     5
# 3  750000007    7510701  Saint-Thomas-d'Aquin     7
# 4  750000009    7510903   Faubourg-Montmartre     9
#
#                                             geometry
# 0  POLYGON ((2.367101341254551 48.86162755885409,...
# 1  POLYGON ((2.361313701339139 48.84858030437791,...
# 2  POLYGON ((2.364561460891576 48.84365746114398,...
# ...

# %%
stations.head()
# Out:
#    nbfreeedock  nbebike station_state  maxbikeoverflow station_type  \
# 0           11        4     Operative                0          yes
# 1           17        1     Operative               18          yes
# 2           15        2     Operative                0          yes
# 3           20        0     Operative                0          yes
# 4           28        0     Operative               31          yes
#
#   overflowactivation station_code densitylevel  nbedock  \
# 0                 no        25006            0       22
# 1                 no        19027            1       18
# 2                 no        10027            1       18
# 3                 no        16110            1       23
# 4                 no         8053            1       29
#
#                         station_name  \
# 0               Place Nelson Mandela
# 1                          Serrurier
# 2                 Dunkerque - Alsace
# 3  Octave Feuillet - Albéric Magnard
# ...

# %% [markdown]
# The districts are polygons and the stations are points.

# %%
districts.plot(figsize=(12, 6))

# %%
stations.plot(column='nbbike', legend=True, figsize=(12, 6))

# %% [markdown]
# The updated data set uses "nbbike" instead of "available_bikes".

# %%
ax = districts.plot(edgecolor='k', color='gray', alpha=0.5, figsize=(20, 10))
stations.plot(ax=ax, column='nbbike', legend=True)
ax.set_axis_off()

# %%
d_new = districts[['objectid', 'n_sq_ar']]
pd.options.display.max_rows = 100
d_new.idxmax(axis=0)
# Out:
# objectid    76
# n_sq_ar     38
# dtype: int64

# %%
districts
# Out:
#     objectid    n_sq_ar
# 0         50  750000003
# 1         56  750000004
# 2         58  750000005
# 3          7  750000007
# 4         17  750000009
# 5         18  750000009
# 6         20  750000010
# 7         21  750000010
# 8         26  750000011
# 9         29  750000012
# 10        79  750000019
# 11        68  750000017
# 12        71  750000017
# 13        49  750000003
# 14        52  750000003
# 15         3  750000006
# 16         5  750000006
# 17         9  750000007
# 18        15  750000009
# 19        28  750000012
# 20        33  750000013
# 21        35  750000014
# 22        37  750000014
# 23        43  750000001
# 24        77  750000019
# 25        65  750000016
# 26        67  750000016
# 27        47  750000002
# 28        51  750000003
# 29        55  750000004
# 30         1  750000005
# 31        11  750000008
# 32        16  750000009
# 33        19  750000010
# 34        22  750000010
# 35        36  750000014
# 36        39  750000015
# ...

# %% [markdown]
# I couldn't find a better way to find the largest district. I subsetted the objectid and area columns, found the row with the max area (36) and inspected the data to see it corresponds to objectid 61, and the name is Charonne.

# %%
stations.hist(column='nbbike')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a333d68>]],
#       dtype=object)

# %%
countries.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# remove Antartica, as the Mercator projection cannot deal with the poles
countries = countries[(countries['NAME'] != "Antarctica")]

# %%
countries_mercator = countries.to_crs(epsg=3395)  # or .to_crs({'init': 'epsg:3395'})

# %%
countries_mercator.plot()

# %%
import fiona
from shapely.geometry import shape

with fiona.drivers():
    with fiona.open("/Users/Charlotte/Documents/4thYear/GISIII/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp") as collection:
        for feature in collection:
            # ... do something with geometry
            geom = shape(feature['geometry'])
            # ... do something with properties
            print(feature['properties']['NAME'])
# Out:
# Fiji
# Tanzania
# W. Sahara
# Canada
# United States of America
# Kazakhstan
# Uzbekistan
# Papua New Guinea
# Indonesia
# Argentina
# Chile
# Dem. Rep. Congo
# Somalia
# Kenya
# Sudan
# Chad
# Haiti
# Dominican Rep.
# Russia
# Bahamas
# Falkland Is.
# Norway
# Greenland
# Fr. S. Antarctic Lands
# Timor-Leste
# South Africa
# Lesotho
# Mexico
# Uruguay
# Brazil
# Bolivia
# Peru
# Colombia
# Panama
# Costa Rica
# Nicaragua
# Honduras
# El Salvador
# Guatemala
# Belize
# Venezuela
# Guyana
# Suriname
# France
# Ecuador
# Puerto Rico
# Jamaica
# Cuba
# Zimbabwe
# Botswana
# Namibia
# Senegal
# Mali
# Mauritania
# Benin
# Niger
# Nigeria
# Cameroon
# Togo
# Ghana
# Côte d'Ivoire
# Guinea
# Guinea-Bissau
# Liberia
# Sierra Leone
# Burkina Faso
# Central African Rep.
# Congo
# Gabon
# Eq. Guinea
# Zambia
# Malawi
# Mozambique
# eSwatini
# Angola
# Burundi
# Israel
# Lebanon
# Madagascar
# Palestine
# Gambia
# Tunisia
# Algeria
# Jordan
# United Arab Emirates
# Qatar
# Kuwait
# Iraq
# Oman
# ...

# %%
geopandas.GeoDataFrame({
    'geometry': [Point(1, 1), Point(2, 2)],
    'attribute1': [1, 2],
    'attribute2': [0.1, 0.2]})
# Out:
#       geometry  attribute1  attribute2
# 0  POINT (1 1)           1         0.1
# 1  POINT (2 2)           2         0.2

# %%
df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Latitude': [-34.58, -15.78, -33.45, 4.60, 10.48],
     'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})

# %%
df['Coordinates']  = list(zip(df.Longitude, df.Latitude))

# %%
df['Coordinates'] = df['Coordinates'].apply(Point)

# %%
gdf = geopandas.GeoDataFrame(df, geometry='Coordinates')

# %%
gdf
# Out:
#            City    Country  Latitude  Longitude            Coordinates
# 0  Buenos Aires  Argentina    -34.58     -58.66  POINT (-58.66 -34.58)
# 1      Brasilia     Brazil    -15.78     -47.91  POINT (-47.91 -15.78)
# 2      Santiago      Chile    -33.45     -70.66  POINT (-70.66 -33.45)
# 3        Bogota   Colombia      4.60     -74.08     POINT (-74.08 4.6)
# 4       Caracas  Venezuela     10.48     -66.86   POINT (-66.86 10.48)
